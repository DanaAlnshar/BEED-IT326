# %% [markdown]
# # Phase 1
#
# ## Project Goal
# *The goal of this project is to perform classification on the Bangalore EEG Epilepsy Dataset in order to predictt brain states using EEG signal features(x1-x16). The aim is to categorize each EEG segment into one of four classes: healthy, generalized epilepsy, focal epilepsy, and seizure-related events.*

# %% [markdown]
# ## Dataset Source
# The dataset was obtained from the UCI Machine Learning Repository.
#
# Link: [Bangalore EEG Epilepsy Dataset](https://archive.ics.uci.edu/dataset/1134/beed%3A%2Bbangalore%2Beeg%2Bepilepsy%2Bdataset?utm_source=chatgpt.com)

# %% [markdown]
# ## Dataset Description
# Provide general information about the dataset:
# - Number and data types of attributes (features): 16 EEG channels,recorded from different regions of the brain using the standard 10-20 electrode placement system.
# - Number of objects (instances/records): The dataset consists of 8000 instances.
# - Class attribute with its values and counts: The class attribute y has 4 categories, each with 2000 instances, making the dataset balanced:
#     * 0 -> Healthy
#     * 1 -> generalized epilepsy
#     * 2 -> Focal epilepsy
#     * 3 -> Seizure-related events

# %%
import pandas as pd

df = pd.read_csv('BEED_Data.csv')
display(df)
# Out:
#        X1   X2   X3   X4   X5   X6  X7  X8  X9  X10  X11  X12  X13  X14  X15  \
# 0       4    7   18   25   28   27  20  10 -10  -18  -20  -16   13   32   12
# 1      87  114  120  106   76   54  28   5 -19  -49  -85 -102 -100  -89  -61
# 2    -131 -133 -140 -131 -123 -108 -58 -51 -70  -77  -76  -76  -73  -57  -40
# 3      68  104   73   34  -12  -26 -38 -36 -67  -88  -25   31   18   -4    6
# 4     -67  -90  -97  -94  -86  -71 -43 -11  23   46   58   50   39   19   -9
# ...   ...  ...  ...  ...  ...  ...  ..  ..  ..  ...  ...  ...  ...  ...  ...
# 7995   -9   -4   -7    2   -9  -14  -7  12  -5   -3   -2   -2  -12   -5    4
# 7996   -8   -4   -7    1   -8  -14  -7  12  -6   -3   -2   -3  -15   -4    4
# 7997   -6   -5   -7    1   -8  -14  -7  12  -7   -3   -2   -4  -16   -4    3
# 7998   -5   -6   -6    1   -8  -13  -7  13  -7   -2   -3   -5  -15   -4    3
# 7999   -4   -7   -5    2   -8  -12  -7  14  -6    0   -3   -6  -13   -4    2
#
#       X16  y
# 0      10  0
# 1     -21  0
# ...
